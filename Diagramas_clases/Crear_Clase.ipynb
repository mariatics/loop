# %% [markdown]
# <img src="01_create_class.png"  style="max-width: 200px; height: 200px;">

# %% [markdown]
# - int id: Asigna un identificador unico al empleado 'Employect'
# - int new_id: variable global de 'Employee'
# - void say_id(): imprime el 'id' de la instancia.

# %%
class Empleyecc: #ESTO ES PARA CREAR LA CLASE(es como el titulo)
    new_id=1 #inicia del 1
    self
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 class Empleyecc: #ESTO ES PARA CREAR LA CLASE(es como el titulo)
#       2     new_id=1 #inicia del 1
#       3     self
#
# Cell In[15], line 3, in Empleyecc()
#       1 class Empleyecc: #ESTO ES PARA CREAR LA CLASE(es como el titulo)
#       2     new_id=1 #inicia del 1
# ----> 3     self
#
# NameError: name 'self' is not defined

# %%
class Employee:
    new_id = 1

    def __init__(self):
        self.id =new_id

        Employee.new_id+= 1

    def say_id(self):
        print(f'Mi id es{self.id}')
